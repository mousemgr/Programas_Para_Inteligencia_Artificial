# %% [markdown]
# Variables y Tipos de Datos

# %%
a = 5

# %%
b = 'Hola, bienvenidos a este curso de Phyton' # Asi se declaran variables en Pyhton

# %%
c = 1.0654

# %%
type (a)
# Out:
# int

# %%
type (b)
# Out:
# str

# %%
type (c)
# Out:
# float

# %% [markdown]
# Operadores Aritmeticos

# %%
a = 2
b = 3
c =  5
d = 10

# %%
 a + d #Suma
# Out:
# 12

# %%
b - c #Resta
# Out:
# -2

# %%
b * c  * a #Multiplicacion
# Out:
# 30

# %%
d / b #Division
# Out:
# 3.3333333333333335

# %%
#Division con redondeo a la izquierda
d // b
# Out:
# 3

# %%
#Residuo o Modulo
70 % 8
# Out:
# 6

# %%
#Potencia
3**3
pow(3,3)
# Out:
# 27

# %% [markdown]
# Operadores Relacionales

# %%
(21 < 23)
# Out:
# True

# %%
'Verde' == 'verde'
# Out:
# False

# %%
87 != (40+47)
# Out:
# False

# %%
45 <= 45
# Out:
# True

# %% [markdown]
# Operadores Logicos

# %%
(10 >= 12) and (9 != 8)
# Out:
# False

# %%
not((23 <= 49) or (10 == 15))
# Out:
# False

# %%
((43 < 65) and (98 != 100) ) or (not(34<=34))
# Out:
# True

# %%
(34>54 and 56<=(7*8) ) or ( ( (95 != 90) and not (30>(6*5)) ) or (not 23 >= 20) or (89 > 4**3))
# Out:
# True

# %%
#96C = 'Hola Mundo'
C96 = 'Hola Mundo'

# %%
lista = [1,2,3]

# %%
contra = 101096

# %%
type(contra)
# Out:
# int

# %%
telefono = 5849382029

# %%
mensaje = 'Club Tesla IA'
LISTA = [45,56,98,23,23]

# %%
max(mensaje)
# Out:
# 'u'

# %%
min(mensaje)
# Out:
# ' '

# %%
len(LISTA)
# Out:
# 5

# %%
len(mensaje)
# Out:
# 13

# %%
max(LISTA)
# Out:
# 98
